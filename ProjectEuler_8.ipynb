# %%
# https://projecteuler.net/problem=8
# The 4 adjacent digits in the thousand digit number 
# n = ...
# that have the greatest product are 9 * 9 * 8 * 9 = 5832
# find the thirteen adjacent digits that have the greatest product, and the product

# %%
n = ...
str_n = str(n)
adjacent_digits = []
for digit in range(0,988): # not the most elegant solution, but just cut it short to catch the last 13
    adjacent_digits.append(str_n[digit: digit+13])

# %%
results = {}
for digits in adjacent_digits:
    product = 1
    for n in range(0,13):
        product = product * int(digits[n])
    results[digits] = product

# %%
results
# Out:
# {'7316717653133': 5000940,
#  '3167176531330': 0,
#  '1671765313306': 0,
#  '6717653133062': 0,
#  '7176531330624': 0,
#  '1765313306249': 0,
#  '7653133062491': 0,
#  '6531330624919': 0,
#  '5313306249192': 0,
#  '3133062491922': 0,
#  '1330624919225': 0,
#  '3306249192251': 0,
#  '3062491922511': 0,
#  '0624919225119': 0,
#  '6249192251196': 4199040,
#  '2491922511967': 4898880,
#  '4919225119674': 9797760,
#  '9192251196744': 9797760,
#  '1922511967442': 2177280,
#  '9225119674426': 13063680,
#  '2251196744265': 7257600,
#  '2511967442657': 25401600,
#  '5119674426574': 50803200,
#  '1196744265747': 71124480,
#  '1967442657474': 284497920,
#  '9674426574742': 568995840,
#  '6744265747423': 189665280,
#  '7442657474235': 158054400,
#  '4426574742355': 112896000,
#  '4265747423553': 84672000,
#  '2657474235534': 84672000,
#  '6574742355349': 381024000,
#  '5747423553491': 63504000,
#  '7474235534919': 114307200,
#  '4742355349194': 65318400,
#  '7423553491949': 146966400,
# ...

# %%
max(results, key = results.get)
# Out:
# '5576689664895'

# %%
results['5576689664895']
# Out:
# 23514624000
